# %%
#import necessary python libraries
import json
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import pandas as pd
import math
from JSON_to_DF import JSON_to_DataFrame
from Lightcurve_class import *
# %matplotlib notebook

# %%
#Create new supernovae object
SN2011fe = Supernovae("../../../OSC_data/JSON_data/SN2011fe.json")

#Load in lightcurves corresponding to unique filter, reference pairs
SN2011fe.load_LightCurves()

#Store metadata from OSC
SN2011fe.meta_data()
# Out:
# /Users/ethanmarx/anaconda/envs/NUREU17/lib/python3.6/site-packages/pandas/core/generic.py:1299: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->['band', 'source', 'telescope']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
#polynomial plot
SN2011fe.Lightcurves['B_9'].polynomial_fit_plot(6)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 6.0528593160795641

# %%
#Kapernka plot
SN2011fe.Lightcurves['B_9'].Bazin_fit_plot(plot=True)
# Out:
# 15.97314860146302

# %%
#get the sources of data 
SN2011fe.Lightcurves['B_9'].get_sources()
# Out:
# array(['2013NewA...20...30M'], dtype=object)
