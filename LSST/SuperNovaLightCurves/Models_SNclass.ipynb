# %%
#import necessary python libraries
import json
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import pandas as pd
import math
from JSON_to_DF import JSON_to_DataFrame
from Lightcurve_class import *
# %matplotlib inline

# %%
#Create new supernovae object
SN2011fe = Supernovae("../../../OSN_data/JSON_data/SN2011fe.json")

#Load in lightcurves corresponding to unique filter, reference pairs
SN2011fe.load_LightCurves()

#Store metadata from OSN
SN2011fe.meta_data()

SN2011fe.z
# Out:
# u'0.000804'

# %%
# Out:
# 684.78166881463744
